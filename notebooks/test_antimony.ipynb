# %%
import libsbml
one_fpath = "/Users/luna/Desktop/CRBM/AMAS_proj/Models/BiggModels/e_coli_core.xml"
reader = libsbml.SBMLReader()
document = reader.readSBML(one_fpath)
model = document.getModel().getPlugin("fbc")
fbc_level = model.getLevel()
fbc_version = model.getVersion()
print(f"FBC version: Level {fbc_level}, Version {fbc_version}")
# Out:
# FBC version: Level 3, Version 1

# %%
import antimony
one_fpath = "e_coli_core.xml"
sbml_model = antimony.loadSBMLFile(one_fpath)
antimony.writeAntimonyFile("antimony_model.txt")
# Out:
# 1

# %%
antimony_model = antimony.getAntimonyString()
print(antimony_model)
# Out:
# // Created by libAntimony v2.15.0
# model *e_coli_core()
#
#   // Compartments and Species:
#   compartment e, c;
#   species M_glc__D_e in e, M_gln__L_c in c, M_gln__L_e in e, M_glu__L_c in c;
#   species M_glu__L_e in e, M_glx_c in c, M_h2o_c in c, M_h2o_e in e, M_h_c in c;
#   species M_h_e in e, M_icit_c in c, M_lac__D_c in c, M_lac__D_e in e, M_mal__L_c in c;
#   species M_mal__L_e in e, M_nad_c in c, M_nadh_c in c, M_nadp_c in c, M_nadph_c in c;
#   species M_nh4_c in c, M_13dpg_c in c, M_nh4_e in e, M_o2_c in c, M_2pg_c in c;
#   species M_o2_e in e, M_3pg_c in c, M_oaa_c in c, M_pep_c in c, M_6pgc_c in c;
#   species M_pi_c in c, M_6pgl_c in c, M_pi_e in e, M_ac_c in c, M_pyr_c in c;
#   species M_pyr_e in e, M_q8_c in c, M_q8h2_c in c, M_r5p_c in c, M_ru5p__D_c in c;
#   species M_ac_e in e, M_acald_c in c, M_s7p_c in c, M_acald_e in e, M_accoa_c in c;
#   species M_succ_c in c, M_succ_e in e, M_succoa_c in c, M_acon_C_c in c;
# ...
